# %%
ls
# Out:
# __notebook__.ipynb

# %%
cp -r /kaggle/input/datasets/imrancoder786/tranformer-from-scratch/Transformer_from_scratch /kaggle/working/

# %%
cd /kaggle/working/Transformer_from_scratch
# Out:
# /kaggle/working/Transformer_from_scratch

# %%
# !ls
# Out:
# attention_visual.ipynb	dataset.py	 model.py
# config.py		inference.ipynb  train.py

# %%
# !python  /kaggle/working/Transformer_from_scratch/train.py
# Out:
# Using device cuda
# ...
# README.md: 1.24kB [00:00, 626kB/s]
# english_tamil_dataset.csv: 100%|████████████| 1.45G/1.45G [00:07<00:00, 201MB/s]
# Generating train split: 100%|█| 5264867/5264867 [00:28<00:00, 183491.01 examples
# [00:02:28] Pre-processing sequences       ██████████████████ 0        /        0Max length of source sentence: 5910
# Max lenght of target sentence: 8413
# processing epoch00:   1%|  | 2972/592298 [23:20<77:09:43,  2.12it/s, loss=6.898]
# Traceback (most recent call last):
#   File "/kaggle/working/Transformer_from_scratch/train.py", line 231, in <module>
#     train_model(config)
#   File "/kaggle/working/Transformer_from_scratch/train.py", line 185, in train_model
#     for batch in batch_iterator :
#                  ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#                ^^^^^^^^
# ...
