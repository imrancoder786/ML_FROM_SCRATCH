# %%
ls
# Out:
# __notebook__.ipynb

# %%
cp -r /kaggle/input/datasets/imrancoder786/transformer-full-code/Transformer_from_scratch /kaggle/working/

# %%
cd /kaggle/working/Transformer_from_scratch
# Out:
# /kaggle/working/Transformer_from_scratch

# %%
# !ls
# Out:
# attention_visual.ipynb	dataset.py	 model.py
# config.py		inference.ipynb  train.py

# %%
# !python  /kaggle/working/Transformer_from_scratch/train.py
# Out:
# Using device cuda
# README.md: 1.24kB [00:00, 748kB/s]
# ...
# english_tamil_dataset.csv: 100%|████████████| 1.45G/1.45G [00:12<00:00, 115MB/s]
# Generating train split: 100%|█| 5264867/5264867 [00:29<00:00, 177718.35 examples
# Filtering dataset for clean sentences...
# Filter: 100%|██████████████| 5264867/5264867 [00:27<00:00, 191350.89 examples/s]
# Clean Dataset size: 200000 pairs
# [00:00:12] Pre-processing sequences       ██████████████████ 0        /        0Max length of source sentence: 192
# Max lenght of target sentence: 223
# Using 2 GPUs for training!
# processing epoch00: 100%|█████| 5625/5625 [1:46:22<00:00,  1.13s/it, loss=5.890]
# Traceback (most recent call last):
#   File "/kaggle/working/Transformer_from_scratch/train.py", line 242, in <module>
#     train_model(config)
#   File "/kaggle/working/Transformer_from_scratch/train.py", line 227, in train_model
# ...
