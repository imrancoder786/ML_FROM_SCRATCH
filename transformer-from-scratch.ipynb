# %%
ls
# Out:
# __notebook__.ipynb

# %%
cp -r /kaggle/input/datasets/imrancoder786/transformer-code-scratch/Transformer_from_scratch /kaggle/working/

# %%
cd /kaggle/working/Transformer_from_scratch
# Out:
# /kaggle/working/Transformer_from_scratch

# %%
# !ls
# Out:
# attention_visual.ipynb	dataset.py	 model.py
# config.py		inference.ipynb  train.py

# %%
# !python  /kaggle/working/Transformer_from_scratch/train.py
# Out:
# Using device cuda
# ...
# README.md: 1.24kB [00:00, 745kB/s]
# english_tamil_dataset.csv: 100%|████████████| 1.45G/1.45G [00:09<00:00, 158MB/s]
# Generating train split: 100%|█| 5264867/5264867 [00:29<00:00, 175598.98 examples
# Filtering dataset for clean sentences...
# Filter: 100%|██████████████| 5264867/5264867 [00:28<00:00, 185827.44 examples/s]
# Clean Dataset size: 200000 pairs
# [00:00:13] Pre-processing sequences       ██████████████████ 0        /        0Max length of source sentence: 192
# Max lenght of target sentence: 223
# Using 2 GPUs for training!
# processing epoch00: 100%|█████| 5625/5625 [1:51:03<00:00,  1.18s/it, loss=5.503]
# --------------------------------------------------------------------------------
# SOURCE:"He said, ""I am the servant of God. He has given me the Book and has appointed me to be a Prophet."
# TARGET:"""நிச்சயமாக நான் அல்லாஹ்வுடைய அடியானாக இருக்கின்றேன். அவன் எனக்கு வேதத்தைக் கொடுத்திருக்கின்றான். இன்னும், என்னை நபியாக ஆக்கியிருக்கின்றான்."
# ...

# %%
# !jupyter nbconvert --to script /kaggle/working/Transformer_from_scratch/inference.ipynb
# !python /kaggle/working/Transformer_from_scratch/inference.py
# Out:
# /usr/local/lib/python3.12/dist-packages/mistune.py:435: SyntaxWarning: invalid escape sequence '\|'
#   cells[i][c] = re.sub('\\\\\|', '|', cell)
# /usr/local/lib/python3.12/dist-packages/nbconvert/filters/filter_links.py:36: SyntaxWarning: invalid escape sequence '\_'
#   text = re.sub(r'_', '\_', text) # Escape underscores in display text
# [NbConvertApp] Converting notebook /kaggle/working/Transformer_from_scratch/inference.ipynb to script
# [NbConvertApp] Writing 830 bytes to /kaggle/working/Transformer_from_scratch/inference.txt
# python3: can't open file '/kaggle/working/Transformer_from_scratch/inference.py': [Errno 2] No such file or directory

# %%
# !jupyter nbconvert --to script /kaggle/working/Transformer_from_scratch/attention_visual.ipynb
# !python /kaggle/working/Transformer_from_scratch/attention_visual.py
# Out:
# [NbConvertApp] Converting notebook /kaggle/working/Transformer_from_scratch/attention_visual.ipynb to script
# [NbConvertApp] Writing 4474 bytes to /kaggle/working/Transformer_from_scratch/attention_visual.py
# using device cuda
# ...
# Filtering dataset for clean sentences...
# Filter: 100%|██████████████| 5264867/5264867 [00:26<00:00, 196990.71 examples/s]
# Clean Dataset size: 200000 pairs
# Max length of source sentence: 192
# Max lenght of target sentence: 223
# Traceback (most recent call last):
#   File "/kaggle/working/Transformer_from_scratch/attention_visual.py", line 31, in <module>
#     model = get_model(config , vocab_src.get_vocab_size() , vocab_tgt.get_vocab_size().to(device))
#                                                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'int' object has no attribute 'to'
